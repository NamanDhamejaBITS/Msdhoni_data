# %%
import pandas as pd
data = pd.read_excel("F:/GithubBITS/Msdhoni data/MS_Dhoni_ODI_record.xlsx")
data
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 0       0           0           1           0     0     0   v Bangladesh
# 1      12          12          11      109.09     2     0   v Bangladesh
# 2      7*           7           2         350     0     1   v Bangladesh
# 3       3           3           7       42.85     0     0     v Pakistan
# 4     148         148         123      120.32    15     4     v Pakistan
# ..    ...         ...         ...         ...   ...   ...            ...
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#             ground       date  odi_number
# 0       Chattogram 2004-12-23  ODI # 2199
# 1            Dhaka 2004-12-26  ODI # 2201
# 2            Dhaka 2004-12-27  ODI # 2202
# 3            Kochi 2005-04-02  ODI # 2235
# 4    Visakhapatnam 2005-04-05  ODI # 2236
# ..             ...        ...         ...
# 345     Manchester 2019-06-27  ODI # 4175
# 346     Birmingham 2019-06-30  ODI # 4179
# 347     Birmingham 2019-07-02  ODI # 4182
# 348          Leeds 2019-07-06  ODI # 4187
# 349     Manchester 2019-07-09  ODI # 4190
#
# [350 rows x 10 columns]

# %%
stri=data.odi_number[0]
stri[6:]
# Out:
# '2199'

# %%
data.odi_number=data.odi_number[6:]
# Out:
# 0      ODI # 2199
# 1      ODI # 2201
# 2      ODI # 2202
# 3      ODI # 2235
# 4      ODI # 2236
# 5      ODI # 2237
# 6      ODI # 2238
# 7      ODI # 2239
# 8      ODI # 2240
# 9      ODI # 2262
# 10     ODI # 2263
# 11     ODI # 2265
# 12     ODI # 2267
# 13     ODI # 2268
# 14     ODI # 2273
# 15     ODI # 2274
# 16     ODI # 2278
# 17     ODI # 2280
# 18     ODI # 2281
# 19     ODI # 2286
# 20     ODI # 2287
# 21     ODI # 2290
# 22     ODI # 2291
# 23     ODI # 2294
# 24     ODI # 2295
# 25     ODI # 2296
# 26     ODI # 2297
# 27     ODI # 2298
# 28     ODI # 2299
# 29     ODI # 2300
# 30     ODI # 2324
# 31     ODI # 2327
# 32     ODI # 2329
# 33     ODI # 2331
# 34     ODI # 2333
# 35     ODI # 2357
# 36     ODI # 2358
# 37     ODI # 2359
# 38     ODI # 2360
# 39     ODI # 2361
# 40     ODI # 2363
# 41     ODI # 2364
# 42     ODI # 2377
# 43     ODI # 2379
# 44     ODI # 2380
# 45     ODI # 2381
# 46     ODI # 2382
# 47     ODI # 2405
# 48     ODI # 2414
# 49     ODI # 2416
# 50     ODI # 2419
# 51     ODI # 2421
# 52     ODI # 2429
# 53     ODI # 2437
# 54     ODI # 2440
# 55     ODI # 2447
# 56     ODI # 2449
# 57     ODI # 2452
# 58     ODI # 2458
# 59     ODI # 2480
# 60     ODI # 2485
# 61     ODI # 2493
# 62     ODI # 2514
# 63     ODI # 2520
# 64     ODI # 2522
# 65     ODI # 2525
# 66     ODI # 2538
# 67     ODI # 2542
# 68     ODI # 2550
# 69     ODI # 2582
# 70     ODI # 2583
# 71     ODI # 2587
# 72     ODI # 2588
# 73     ODI # 2589
# 74     ODI # 2593
# 75     ODI # 2595
# 76     ODI # 2608
# 77     ODI # 2611
# 78     ODI # 2613
# 79     ODI # 2616
# 80     ODI # 2617
# 81     ODI # 2618
# 82     ODI # 2619
# 83     ODI # 2620
# 84     ODI # 2621
# 85     ODI # 2623
# 86     ODI # 2625
# 87     ODI # 2627
# 88     ODI # 2629
# 89     ODI # 2631
# 90     ODI # 2632
# 91     ODI # 2643
# 92     ODI # 2644
# 93     ODI # 2645
# 94     ODI # 2646
# 95     ODI # 2647
# 96     ODI # 2670
# 97     ODI # 2672
# 98     ODI # 2675
# 99     ODI # 2676
# 100    ODI # 2680
# 101    ODI # 2681
# 102    ODI # 2685
# 103    ODI # 2686
# 104    ODI # 2688
# 105    ODI # 2689
# 106    ODI # 2705
# 107    ODI # 2706
# 108    ODI # 2707
# 109    ODI # 2716
# 110    ODI # 2717
# 111    ODI # 2721
# 112    ODI # 2730
# 113    ODI # 2732
# 114    ODI # 2735
# 115    ODI # 2742
# 116    ODI # 2745
# 117    ODI # 2750
# 118    ODI # 2755
# 119    ODI # 2756
# 120    ODI # 2774
# 121    ODI # 2777
# 122    ODI # 2778
# 123    ODI # 2781
# 124    ODI # 2783
# 125    ODI # 2806
# 126    ODI # 2810
# 127    ODI # 2813
# 128    ODI # 2815
# 129    ODI # 2818
# 130    ODI # 2821
# 131    ODI # 2822
# 132    ODI # 2823
# 133    ODI # 2824
# 134    ODI # 2825
# 135    ODI # 2852
# 136    ODI # 2853
# 137    ODI # 2854
# 138    ODI # 2855
# 139    ODI # 2886
# 140    ODI # 2887
# 141    ODI # 2889
# 142    ODI # 2898
# 143    ODI # 2901
# 144    ODI # 2904
# 145    ODI # 2913
# 146    ODI # 2915
# 147    ODI # 2918
# 148    ODI # 2919
# 149    ODI # 2923
# 150    ODI # 2925
# 151    ODI # 2932
# 152    ODI # 2933
# 153    ODI # 2936
# 154    ODI # 2938
# 155    ODI # 2939
# 156    ODI # 2941
# 157    ODI # 2942
# 158    ODI # 2943
# 159    ODI # 2961
# 160    ODI # 2962
# 161    ODI # 2963
# 162    ODI # 2993
# 163    ODI # 2996
# 164    ODI # 2999
# 165    ODI # 3001
# 166    ODI # 3030
# 167    ODI # 3032
# 168    ODI # 3038
# 169    ODI # 3039
# 170    ODI # 3040
# 171    ODI # 3060
# 172    ODI # 3079
# 173    ODI # 3080
# 174    ODI # 3082
# 175    ODI # 3084
# 176    ODI # 3087
# 177    ODI # 3100
# 178    ODI # 3110
# 179    ODI # 3121
# 180    ODI # 3124
# 181    ODI # 3128
# 182    ODI # 3141
# 183    ODI # 3143
# 184    ODI # 3147
# 185    ODI # 3148
# 186    ODI # 3186
# 187    ODI # 3187
# 188    ODI # 3189
# 189    ODI # 3191
# 190    ODI # 3195
# 191    ODI # 3199
# 192    ODI # 3201
# 193    ODI # 3205
# 194    ODI # 3207
# 195    ODI # 3210
# 196    ODI # 3231
# 197    ODI # 3233
# 198    ODI # 3237
# 199    ODI # 3239
# 200    ODI # 3244
# 201    ODI # 3250
# 202    ODI # 3251
# 203    ODI # 3259
# 204    ODI # 3261
# 205    ODI # 3263
# 206    ODI # 3291
# 207    ODI # 3292
# 208    ODI # 3293
# 209    ODI # 3294
# 210    ODI # 3295
# 211    ODI # 3314
# 212    ODI # 3315
# 213    ODI # 3316
# 214    ODI # 3318
# 215    ODI # 3320
# 216    ODI # 3322
# 217    ODI # 3327
# 218    ODI # 3329
# 219    ODI # 3363
# 220    ODI # 3368
# 221    ODI # 3372
# 222    ODI # 3376
# 223    ODI # 3377
# 224    ODI # 3380
# 225    ODI # 3388
# 226    ODI # 3419
# 227    ODI # 3420
# 228    ODI # 3421
# 229    ODI # 3422
# 230    ODI # 3424
# 231    ODI # 3428
# 232    ODI # 3436
# 233    ODI # 3437
# 234    ODI # 3439
# 235    ODI # 3442
# 236    ODI # 3443
# 237    ODI # 3444
# 238    ODI # 3456
# 239    ODI # 3458
# 240    ODI # 3462
# 241    ODI # 3465
# 242    ODI # 3467
# 243    ODI # 3517
# 244    ODI # 3520
# 245    ODI # 3523
# 246    ODI # 3525
# 247    ODI # 3531
# 248    ODI # 3533
# 249    ODI # 3535
# 250    ODI # 3582
# 251    ODI # 3586
# 252    ODI # 3592
# 253    ODI # 3595
# 254    ODI # 3602
# 255    ODI # 3610
# 256    ODI # 3618
# 257    ODI # 3625
# 258    ODI # 3631
# 259    ODI # 3636
# 260    ODI # 3641
# 261    ODI # 3645
# 262    ODI # 3658
# 263    ODI # 3660
# 264    ODI # 3661
# 265    ODI # 3689
# 266    ODI # 3692
# 267    ODI # 3695
# 268    ODI # 3698
# 269    ODI # 3700
# 270    ODI # 3723
# 271    ODI # 3724
# 272    ODI # 3725
# 273    ODI # 3726
# 274    ODI # 3727
# 275    ODI # 3742
# 276    ODI # 3744
# 277    ODI # 3746
# 278    ODI # 3796
# 279    ODI # 3797
# 280    ODI # 3798
# 281    ODI # 3799
# 282    ODI # 3800
# 283    ODI # 3819
# 284    ODI # 3821
# 285    ODI # 3824
# 286    ODI # 3878
# 287    ODI # 3882
# 288    ODI # 3886
# 289    ODI # 3891
# 290    ODI # 3894
# 291    ODI # 3895
# 292    ODI # 3896
# 293    ODI # 3898
# 294    ODI # 3900
# 295    ODI # 3902
# 296    ODI # 3905
# 297    ODI # 3906
# 298    ODI # 3907
# 299    ODI # 3908
# 300    ODI # 3909
# 301    ODI # 3910
# 302    ODI # 3912
# 303    ODI # 3914
# 304    ODI # 3917
# 305    ODI # 3919
# 306    ODI # 3928
# 307    ODI # 3931
# 308    ODI # 3932
# 309    ODI # 3939
# 310    ODI # 3941
# 311    ODI # 3942
# 312    ODI # 3969
# 313    ODI # 3970
# 314    ODI # 3971
# 315    ODI # 3973
# 316    ODI # 3976
# 317    ODI # 3978
# 318    ODI # 4014
# 319    ODI # 4016
# 320    ODI # 4018
# 321    ODI # 4039
# 322    ODI # 4040
# 323    ODI # 4042
# 324    ODI # 4044
# 325    ODI # 4046
# 326    ODI # 4048
# 327    ODI # 4056
# 328    ODI # 4059
# 329    ODI # 4062
# 330    ODI # 4063
# 331    ODI # 4064
# 332    ODI # 4077
# 333    ODI # 4078
# 334    ODI # 4079
# 335    ODI # 4082
# 336    ODI # 4085
# 337    ODI # 4092
# 338    ODI # 4102
# 339    ODI # 4106
# 340    ODI # 4109
# 341    ODI # 4150
# 342    ODI # 4155
# 343    ODI # 4161
# 344    ODI # 4169
# 345    ODI # 4175
# 346    ODI # 4179
# 347    ODI # 4182
# 348    ODI # 4187
# 349    ODI # 4190
# Name: odi_number, dtype: object

# %%
data
# Out:
#     score runs_scored balls_faced strike_rate fours sixes     opposition  \
# 0       0           0           1           0     0     0   v Bangladesh
# 1      12          12          11      109.09     2     0   v Bangladesh
# 2      7*           7           2         350     0     1   v Bangladesh
# 3       3           3           7       42.85     0     0     v Pakistan
# 4     148         148         123      120.32    15     4     v Pakistan
# ..    ...         ...         ...         ...   ...   ...            ...
# 345   56*          56          61        91.8     3     2  v West Indies
# 346   42*          42          31      135.48     4     1      v England
# 347    35          35          33      106.06     4     0   v Bangladesh
# 348   DNB           -           -           -     -     -    v Sri Lanka
# 349    50          50          72       69.44     1     1  v New Zealand
#
#             ground       date  odi_number
# 0       Chattogram 2004-12-23         NaN
# 1            Dhaka 2004-12-26         NaN
# 2            Dhaka 2004-12-27         NaN
# 3            Kochi 2005-04-02         NaN
# 4    Visakhapatnam 2005-04-05         NaN
# ..             ...        ...         ...
# 345     Manchester 2019-06-27  ODI # 4175
# 346     Birmingham 2019-06-30  ODI # 4179
# 347     Birmingham 2019-07-02  ODI # 4182
# 348          Leeds 2019-07-06  ODI # 4187
# 349     Manchester 2019-07-09  ODI # 4190
#
# [350 rows x 10 columns]

# %%
for i in range(len(data)):
    data.odi_number[i]=int(str(data.odi_number[i])[6:])

print(data.odi_number.head(5))
# Out:
# 0    2199
# 1    2201
# 2    2202
# 3    2235
# 4    2236
# Name: odi_number, dtype: object
# C:\Users\Naman\AppData\Local\Temp/ipykernel_20476/2387874491.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.odi_number[i]=int(str(data.odi_number[i])[6:])

# %%
data.isna().sum()
# Out:
# score          0
# runs_scored    0
# balls_faced    0
# strike_rate    0
# fours          0
# sixes          0
# opposition     0
# ground         0
# date           0
# odi_number     0
# dtype: int64

# %%
len(data)
# Out:
# 350

# %%
a=[]
for i in range(0,len(data)):
        if( data["fours"][i] =='-'):
            data["fours"][i] = 0
        if( data["sixes"][i] =='-'):
            data["sixes"][i] = 0
        if(data.score[i]=="DNB" or data.score[i]=="TDNB" or data.score[i]=="absent"):
            a.append(i)
data.drop(a,inplace=True)
data.reset_index(drop=True, inplace=True)
data.drop(labels="score",axis=1,inplace=True) #Remove the Unnamed column


#data
# Out:
#     runs_scored balls_faced strike_rate fours sixes     opposition  \
# 0             0           1           0     0     0   v Bangladesh
# 1            12          11      109.09     2     0   v Bangladesh
# 2             7           2         350     0     1   v Bangladesh
# 3             3           7       42.85     0     0     v Pakistan
# 4           148         123      120.32    15     4     v Pakistan
# ..          ...         ...         ...   ...   ...            ...
# 292          28          52       53.84     3     0  v Afghanistan
# 293          56          61        91.8     3     2  v West Indies
# 294          42          31      135.48     4     1      v England
# 295          35          33      106.06     4     0   v Bangladesh
# 296          50          72       69.44     1     1  v New Zealand
#
#             ground       date odi_number
# 0       Chattogram 2004-12-23       2199
# 1            Dhaka 2004-12-26       2201
# 2            Dhaka 2004-12-27       2202
# 3            Kochi 2005-04-02       2235
# 4    Visakhapatnam 2005-04-05       2236
# ..             ...        ...        ...
# 292    Southampton 2019-06-22       4169
# 293     Manchester 2019-06-27       4175
# 294     Birmingham 2019-06-30       4179
# 295     Birmingham 2019-07-02       4182
# 296     Manchester 2019-07-09       4190
#
# [297 rows x 9 columns]

# %%
ru=s4=s6=sr=0
for i in range(0, len(data)):
    ru=ru+int(data["runs_scored"][i])
    sr=sr+int(data["strike_rate"][i])
    s4=s4+int(data["fours"][i])
    s6=s6+int(data["sixes"][i])
print(f"Runs:{ru}\nFours:{s4}\nSixes:{s6}\nAverage Strike rate={sr/len(data)}\nMatches Batted in:{len(data)}")
# Out:
# Runs:10773
# Fours:826
# Sixes:229
# Average Strike rate=87.51178451178451
# Matches Batted in:297

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.pie(np.array([s4*4,s6*6,ru-s4*4-s6*6]),labels=["4s","6s","Runs w/o 4s and 6s"],normalize=True,explode = [0.1,0.2,0],autopct='%1.0f%%')
plt.show()

# %%
ru=0
s4=0
s6=0
opp=str(input("Enter the opposition name: "))
for i in range(0, len(data)):
    if(data.opposition[i][2:]==opp):
    
        ru=ru+int(data["runs_scored"][i])
        s4=s4+int(data["fours"][i])
        s6=s6+int(data["sixes"][i])
print(f"Runs:{ru}\nFours:{s4}\nSixes:{s6}")

plt.pie(np.array([s4*4,s6*6,ru-s4*4-s6*6]),labels=["4s","6s","Runs w/o 4s and 6s"],normalize=True,explode = [0.1,0.2,0],autopct='%1.0f%%')
plt.show()
# Out:
# Enter the opposition name: England
# Runs:1546
# Fours:129
# Sixes:34

# %%
ru=0
s4=0
s6=0
gnd=str(input("Enter the ground name: "))
for i in range(0, len(data)):
    if(data.ground[i]==gnd):
    
        ru=ru+int(data["runs_scored"][i])
        s4=s4+int(data["fours"][i])
        s6=s6+int(data["sixes"][i])
print(f"Runs:{ru}\nFours:{s4}\nSixes:{s6}")

plt.pie(np.array([s4*4,s6*6,ru-s4*4-s6*6]),labels=["4s","6s","Runs w/o 4s and 6s"],normalize=True,explode = [0.1,0.2,0],autopct='%1.0f%%')
plt.show()
# Out:
# Enter the ground name: Visakhapatnam
# Runs:260
# Fours:22
# Sixes:10
